# %% [markdown]
# # **Housing Price Predictor**

# %% [markdown]
# ## Load the Dataset
# Let's Load the Dataset from the *train.csv* file which was downloaded from Kaggle with help of pandas.

# %%
import numpy as np
import pandas as pd

housing = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
housing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Take a Breif Look at the Structure of the Dataset.

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# # Split Training and Testing Set.

# %% [markdown]
# We are going to Split the *Training and Testing Set* because for testing our model we need to use a different dataset and for training we also need a different dataset and the propotion of the training and testing dataset is going to be :-
# - Training = 80%
# - Testing = 20%
# Because this is the most Relevant according to our Needs.

# %% [markdown]
# We are going to use the `train_test_split` methode from `sklearn.model_selection` this seperates the dataset according to our instructions and normally it splits them in random order but since we have declared `random_state=42` so no matter how many times we split this dataset the output will be same otherwise the model will eventually see all the dataset and make very good predictions on `Training Set` which will result in the Condition of `Overfitting`.

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
len(train_set)
# Out:
# 1168

# %%
len(test_set)
# Out:
# 292

# %%
housing = train_set.copy()

# %%
housing.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 254    255          20       RL         70.0     8400   Pave   NaN      Reg
# 1066  1067          60       RL         59.0     7837   Pave   NaN      IR1
# 638    639          30       RL         67.0     8777   Pave   NaN      Reg
# 799    800          50       RL         60.0     7200   Pave   NaN      Reg
# 380    381          50       RL         50.0     5000   Pave  Pave      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 254          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1066         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 638          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 799          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 380          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1168 entries, 254 to 1126
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    951 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          74 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
housing.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000   951.000000    1168.000000  1168.000000
# mean    730.904966    56.849315    70.343849   10689.642123     6.121575
# std     425.369088    42.531862    24.897021   10759.366198     1.367619
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     360.750000    20.000000    59.000000    7587.250000     5.000000
# 50%     732.500000    50.000000    70.000000    9600.000000     6.000000
# 75%    1101.750000    70.000000    80.000000   11700.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1162.000000  1168.000000  ...
# mean      5.584760  1970.965753   1984.897260   103.771945   446.023973  ...
# std       1.116062    30.675495     20.733955   173.032238   459.070977  ...
# ...

# %% [markdown]
# # Drop Features to Clean Dataset

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DatasetCleaner(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, dataset):
        return self

    def drop_id(self, dataset):
        dataset = dataset.drop("Id", axis=1)
        return dataset

    def remove_categorical_columns(self, dataset):
        num_dataset = dataset.select_dtypes(include = ['float64', 'int64'])
        return num_dataset

    def transform(self, dataset):
        dataset = self.drop_id(dataset)
        dataset = self.remove_categorical_columns(dataset)
        return dataset

cleaner = DatasetCleaner()
housing_num = cleaner.transform(housing)
housing_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1168 entries, 254 to 1126
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   LotFrontage    951 non-null    float64
#  2   LotArea        1168 non-null   int64
#  3   OverallQual    1168 non-null   int64
#  4   OverallCond    1168 non-null   int64
#  5   YearBuilt      1168 non-null   int64
#  6   YearRemodAdd   1168 non-null   int64
#  7   MasVnrArea     1162 non-null   float64
#  8   BsmtFinSF1     1168 non-null   int64
#  9   BsmtFinSF2     1168 non-null   int64
#  10  BsmtUnfSF      1168 non-null   int64
#  11  TotalBsmtSF    1168 non-null   int64
#  12  1stFlrSF       1168 non-null   int64
#  13  2ndFlrSF       1168 non-null   int64
#  14  LowQualFinSF   1168 non-null   int64
#  15  GrLivArea      1168 non-null   int64
#  16  BsmtFullBath   1168 non-null   int64
#  17  BsmtHalfBath   1168 non-null   int64
# ...

# %% [markdown]
# # Replace `NaN` values with `mean`.

# %%
class NaN_Handler(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, dataset):
        return self

    def transform(self, dataset):
        for column in dataset:
            column_mean = dataset[column].mean()
            filled_column = dataset[column].fillna(column_mean)
            dataset[column] = filled_column
        return dataset

nan_handler = NaN_Handler()
housing_num = nan_handler.transform(housing_num)
housing_num.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 254           20         70.0     8400            5            6       1957
# 1066          60         59.0     7837            6            7       1993
# 638           30         67.0     8777            5            7       1910
# 799           50         60.0     7200            5            7       1937
# 380           50         50.0     5000            5            6       1924
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 254           1957         0.0         922           0  ...         250
# 1066          1994         0.0           0           0  ...           0
# 638           1950         0.0           0           0  ...         328
# 799           1950       252.0         569           0  ...           0
# 380           1950         0.0         218           0  ...           0
#
# ...

# %% [markdown]
# ## Correlation Matrix

# %%
corr_matrix = housing_num.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.785555
# GrLivArea        0.695652
# GarageCars       0.640991
# GarageArea       0.624139
# TotalBsmtSF      0.597766
# 1stFlrSF         0.587883
# FullBath         0.552546
# TotRmsAbvGrd     0.520388
# YearBuilt        0.516501
# YearRemodAdd     0.508593
# GarageYrBlt      0.462985
# MasVnrArea       0.458948
# Fireplaces       0.457549
# BsmtFinSF1       0.359460
# WoodDeckSF       0.329843
# 2ndFlrSF         0.314030
# LotFrontage      0.312137
# OpenPorchSF      0.299969
# HalfBath         0.280481
# LotArea          0.266204
# BsmtFullBath     0.226346
# BsmtUnfSF        0.222487
# BedroomAbvGr     0.156211
# ScreenPorch      0.119172
# PoolArea         0.115630
# 3SsnPorch        0.051532
# MoSold           0.041890
# BsmtFinSF2      -0.005731
# YrSold          -0.009099
# LowQualFinSF    -0.011189
# MiscVal         -0.020179
# BsmtHalfBath    -0.048346
# OverallCond     -0.074391
# MSSubClass      -0.088081
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(corr_matrix, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Train and Test Different Models and pick the Best of Them
# ## Choose Some of the Best Models for this Dataset.
# For the Best Scenario I have already Picked up Some of the Best Models which are Suitable for our Dataset.
# - Random Forest Regressor Model.
# - Gradient Boosted Trees Model.
# - Cart Model.
# - Distributed Gradient Boosted Trees Model.

# %%
X, y = housing_num.drop("SalePrice", axis=1), housing_num["SalePrice"]
X
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 254           20         70.0     8400            5            6       1957
# 1066          60         59.0     7837            6            7       1993
# 638           30         67.0     8777            5            7       1910
# 799           50         60.0     7200            5            7       1937
# 380           50         50.0     5000            5            6       1924
# ...          ...          ...      ...          ...          ...        ...
# 1095          20         78.0     9317            6            5       2006
# 1130          50         65.0     7804            4            3       1928
# 1294          20         60.0     8172            5            7       1955
# 860           50         55.0     7642            7            8       1918
# 1126         120         53.0     3684            7            5       2007
#
# ...

# %%
y
# Out:
# 254     145000
# 1066    178000
# 638      85000
# 799     175000
# 380     127000
#          ...
# 1095    176432
# 1130    135000
# 1294    115000
# 860     189950
# 1126    174000
# Name: SalePrice, Length: 1168, dtype: int64

# %% [markdown]
# ## Train `Random Forest Regressor` Model on this Dataset

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=3)
grid_search.fit(X, y)

forest_reg = grid_search.best_estimator_
forest_reg
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = forest_reg.predict(X)
forest_mse = mean_squared_error(y, housing_predictions)
forest_mse = np.sqrt(forest_mse)
forest_mse
# Out:
# 11288.387657650193

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(forest_reg, X, y, scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-scores)

# %%
def display_rmse_scores(scores):
    print(f"Scores: \n {scores}")
    print(f"Mean: {scores.mean()}")
    print(f"Standard devitation: {scores.std()}")

display_rmse_scores(forest_rmse_scores)
# Out:
# Scores:
#  [19282.67678645 35914.09544939 23833.89501104 43112.97793871
#  43238.27327168 34569.26708528 27389.5587398  23665.8366907
#  26346.89475306 24264.46242235]
# Mean: 30161.793814847188
# Standard devitation: 8055.150459071654

# %% [markdown]
# ## Train and Test `Gradient Boosted Trees` Model on our Dataset.

# %%
from sklearn.ensemble import GradientBoostingRegressor
n_estimators = 100  # Number of boosting stages (trees)
learning_rate = 0.1  # Shrinkage parameter
max_depth = 3  # Maximum depth of each tree

gbt_model = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth)
gbt_model.fit(X, y)
# Out:
# GradientBoostingRegressor()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5]
}

grid_search = GridSearchCV(GradientBoostingRegressor(), param_grid, cv=3)
grid_search.fit(X, y)

gbt_model = grid_search.best_estimator_
gbt_model
# Out:
# GradientBoostingRegressor(learning_rate=0.2)

# %%
housing_predictions = gbt_model.predict(X)
gbt_mse = mean_squared_error(y, housing_predictions)
gbt_mse = np.sqrt(gbt_mse)
gbt_mse
# Out:
# 11620.88130358635

# %%
scores = cross_val_score(gbt_model, X, y, scoring="neg_mean_squared_error", cv=10)
gbt_mse_scores = np.sqrt(-scores)

# %%
display_rmse_scores(gbt_mse_scores)
# Out:
# Scores:
#  [20275.28020931 45642.86682231 22618.05911681 45132.35598371
#  33964.74607579 32034.98080705 24644.77938002 28821.25829977
#  24243.95549131 20174.73547612]
# Mean: 29755.301766219396
# Standard devitation: 8954.038103324021

# %% [markdown]
# ## Train `Cart` Model on Our Dataset.

# %%
from sklearn.tree import DecisionTreeRegressor
max_depth = None   # Maximum depth of the tree
cart_model = DecisionTreeRegressor(max_depth=max_depth, random_state=42)
cart_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid, cv=3)
grid_search.fit(X, y)

cart_model = grid_search.best_estimator_
cart_model
# Out:
# DecisionTreeRegressor(min_samples_leaf=2, min_samples_split=10, random_state=42)

# %%
housing_predictions = cart_model.predict(X)
cart_mse = mean_squared_error(y, housing_predictions)
cart_mse = np.sqrt(cart_mse)
cart_mse
# Out:
# 14373.459777455611

# %%
scores = cross_val_score(cart_model, X, y, scoring="neg_mean_squared_error", cv=10)
cart_mse_scores = np.sqrt(-scores)

# %%
display_rmse_scores(cart_mse_scores)
# Out:
# Scores:
#  [34570.21964404 61469.25128161 45036.26124765 44433.19383195
#  52293.33990243 41588.99607707 37522.78569626 34505.47949552
#  39814.80992492 32434.59959349]
# Mean: 42366.893669494944
# Standard devitation: 8524.397827597155

# %% [markdown]
# ## Train `Distributed Gradient Boosted Trees` Model on this Dataset.

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5]
}

# Create a GradientBoostingRegressor model
dgbt_model = GradientBoostingRegressor()

# Create GridSearchCV instance
grid_search = GridSearchCV(dgbt_model, param_grid, cv=3)

# Fit the GridSearchCV on the training data
grid_search.fit(X, y)

# Get the best estimator from the grid search
dgbt_model = grid_search.best_estimator_

# %%
housing_predictions = dgbt_model.predict(X)
dgbt_mse = mean_squared_error(y, housing_predictions)
dgbt_mse = np.sqrt(dgbt_mse)
dgbt_mse
# Out:
# 11543.426950149975

# %%
scores = cross_val_score(dgbt_model, X, y, scoring="neg_mean_squared_error", cv=10)
dgbt_mse_scores = np.sqrt(-scores)

# %%
display_rmse_scores(dgbt_mse_scores)
# Out:
# Scores:
#  [18727.56244636 45459.71189488 21992.65132588 45202.97602625
#  36389.08563486 30348.76858071 25774.42293588 24542.72809889
#  22887.36980455 20120.86407181]
# Mean: 29144.614082007098
# Standard devitation: 9438.050700833077

# %% [markdown]
# # Compairing all of the Models that we have Trained

# %%
Models = [
    "Random Forest",
    "GBT",
    "Cart",
    "Distributed GBT",
]

RMSE = [
    forest_rmse_scores.mean(),
    gbt_mse_scores.mean(),
    cart_mse_scores.mean(),
    dgbt_mse_scores.mean()
]

# %%
# Creating a bar chart
plt.bar(Models, RMSE)

# Adding labels and title
plt.xlabel('Models')
plt.ylabel('RMSE')
plt.title('Bar Chart of Random Forest Regressor, GBT, Cart, and Distributed GBT')

# Display the plot
plt.show()

# %% [markdown]
# As we can see that **Cart** Out Performes everyone on the **Training Dataset**. So we will Test this on the Testing Dataset.

# %% [markdown]
# # Use **Every** Model on Testing Set.

# %%
from sklearn.pipeline import Pipeline

transformer_pipeline = Pipeline([
    ("cleaner", DatasetCleaner()),
    ("nan_handler", NaN_Handler()),
])
transformer_pipeline
# Out:
# Pipeline(steps=[('cleaner', DatasetCleaner()), ('nan_handler', NaN_Handler())])

# %%
prepared_test = transformer_pipeline.fit_transform(test_set)
prepared_test
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 892           20         70.0     8414            6            8       1963
# 1105          60         98.0    12256            8            5       1994
# 413           30         56.0     8960            5            6       1927
# 522           50         50.0     5000            6            7       1947
# 1036          20         89.0    12898            9            5       2007
# ...          ...          ...      ...          ...          ...        ...
# 479           30         50.0     5925            4            7       1937
# 1361          20        124.0    16158            7            5       2005
# 802           60         63.0     8199            7            5       2005
# 651           70         60.0     9084            4            5       1940
# 722           20         70.0     8120            4            7       1970
#
# ...

# %%
X, y = prepared_test.drop("SalePrice", axis=1), prepared_test["SalePrice"]

# %%
X
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 892           20         70.0     8414            6            8       1963
# 1105          60         98.0    12256            8            5       1994
# 413           30         56.0     8960            5            6       1927
# 522           50         50.0     5000            6            7       1947
# 1036          20         89.0    12898            9            5       2007
# ...          ...          ...      ...          ...          ...        ...
# 479           30         50.0     5925            4            7       1937
# 1361          20        124.0    16158            7            5       2005
# 802           60         63.0     8199            7            5       2005
# 651           70         60.0     9084            4            5       1940
# 722           20         70.0     8120            4            7       1970
#
# ...

# %%
y
# Out:
# 892     154500
# 1105    325000
# 413     115000
# 522     159000
# 1036    315500
#          ...
# 479      89471
# 1361    260000
# 802     189000
# 651     108000
# 722     124500
# Name: SalePrice, Length: 292, dtype: int64

# %% [markdown]
# # Test Every Model we have Trained Yet.

# %%
forest_reg_predictions = forest_reg.predict(X)
gbt_model_predictions = gbt_model.predict(X)
cart_model_predictions = cart_model.predict(X)
dgbt_model_predictions = dgbt_model.predict(X)

# %%
forest_reg_mse = mean_squared_error(y, forest_reg_predictions)
forest_reg_mse = np.sqrt(forest_reg_mse)
forest_reg_mse
# Out:
# 29381.621654253206

# %%
scores = cross_val_score(forest_reg, X, y, scoring="neg_mean_squared_error", cv=10)
forest_reg_scores = np.sqrt(-scores)
display_rmse_scores(forest_reg_scores)
# Out:
# Scores:
#  [26009.70626357 32880.32257321 46716.263852   23345.97989844
#  58359.51006338 43176.84751462 30818.36004479 25703.34983066
#  21105.23080529 22457.22177566]
# Mean: 33057.27926216323
# Standard devitation: 11779.18103142036

# %%
gbt_model_mse = mean_squared_error(y, gbt_model_predictions)
gbt_model_mse = np.sqrt(gbt_model_mse)

# %%
scores = cross_val_score(gbt_model, X, y, scoring="neg_mean_squared_error", cv=10)
gbt_mse_scores = np.sqrt(-scores)
display_rmse_scores(gbt_mse_scores)
# Out:
# Scores:
#  [20195.21104821 34773.28648606 50167.84902144 31090.41412369
#  55451.57894752 41289.39747499 28805.78332019 24654.92952424
#  28772.66631859 23876.94481657]
# Mean: 33907.806108150675
# Standard devitation: 11037.967441858478

# %%
cart_mse = mean_squared_error(y, cart_model_predictions)
cart_mse = np.sqrt(cart_mse)

# %%
scores = cross_val_score(cart_model, X, y, scoring="neg_mean_squared_error", cv=10)
cart_mse_scores = np.sqrt(-scores)
display_rmse_scores(cart_mse_scores)
# Out:
# Scores:
#  [31819.63627309 88002.65615476 60964.33116281 28548.02510207
#  71260.13496541 44416.23590718 39422.13810412 33539.68717363
#  43685.00968776 38225.48792305]
# Mean: 47988.33424538861
# Standard devitation: 18328.083238468

# %%
dgbt_model_mse = mean_squared_error(y, dgbt_model_predictions)
dgbt_model_mse = np.sqrt(cart_mse)

# %%
scores = cross_val_score(dgbt_model, X, y, scoring="neg_mean_squared_error", cv=10)
dgbt_mse_scores = np.sqrt(-scores)
display_rmse_scores(dgbt_mse_scores)
# Out:
# Scores:
#  [19916.52845861 34098.37558058 52476.6749546  26791.50546898
#  52146.57791883 30189.65369651 30501.19638842 24016.74712914
#  25795.19457805 23967.67984825]
# Mean: 31990.01340219784
# Standard devitation: 10839.712040973243

# %% [markdown]
# Let's Plot A Graph of all the Models.

# %%
Models = [
    "Random Forest",
    "GBT",
    "Cart",
    "Distributed GBT",
]

RMSE = [
    forest_reg_scores.mean(),
    gbt_model_mse.mean(),
    cart_mse_scores.mean(),
    dgbt_mse_scores.mean()
]

# %%
# Creating a bar chart
plt.bar(Models, RMSE)

# Adding labels and title
plt.xlabel('Models')
plt.ylabel('RMSE')
plt.title('Bar Chart of Random Forest Regressor, GBT, Cart, and Distributed GBT')

# Display the plot
plt.show()

# %% [markdown]
# As we can see that the **Cart** Model is still Overperforming Everyone Else which means it is not overfitting the **Training Dataset**.

# %% [markdown]
# ## Save our **Cart Model** using joblib

# %%
import joblib

joblib.dump(cart_model, "House_Price_Predictor_Cart.pkl")
final_reg_loaded = joblib.load("House_Price_Predictor_Cart.pkl")
